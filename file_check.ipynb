# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/AI_DL/images'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/AI_DL/images

# %%
import os

# %%
basepath = os.getcwd()
print(basepath)
my_dirs = [d for d in os.listdir(os.getcwd()) if os.path.isdir(os.path.join(os.getcwd(), d))]
# Out:
# /content/drive/MyDrive/AI_DL/images

# %%
for element in my_dirs:
  count = len(os.listdir('/content/drive/MyDrive/AI_DL/images/'+element+"/images"))
  print(element+" has total number of: "+str(count))
# Out:
# images_004 has total number of: 10000
# images_007 has total number of: 10000
# images_003 has total number of: 10000
# images_005 has total number of: 10000
# images_002 has total number of: 10000
# images_006 has total number of: 10000
# images_001 has total number of: 4999
# images_009 has total number of: 10000
# images_008 has total number of: 10000
# images_011 has total number of: 10000
# images_010 has total number of: 10000
# images_012 has total number of: 6275
